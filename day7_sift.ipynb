# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.figure(figsize=(8, 8))

# %% [markdown]
# ## sift 算法

# %%
img = cv2.imread('./assets/1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

sift = cv2.xfeatures2d.SIFT_create()
kp = sift.detect(gray, None)

image = img.copy()
image = cv2.drawKeypoints(gray, kp, image)

plt.figure(figsize=(12, 12))
plt.subplot(231), plt.imshow(img), plt.title("origion"), plt.axis('off')
plt.subplot(232), plt.imshow(image), plt.title("keyPoints"), plt.axis('off')
# Out:
# (<Axes: title={'center': 'keyPoints'}>,
#  <matplotlib.image.AxesImage at 0x7f0af3ad4850>,
#  Text(0.5, 1.0, 'keyPoints'),
#  (-0.5, 1278.5, 1705.5, -0.5))

# %% [markdown]
# ### 计算特征

# %%
kp, des = sift.compute(gray, kp)

print(np.array(kp).shape)

print(des.shape)

# 每个关键点都是 128 维的向量
print(des[0])
# Out:
# (840,)
# (840, 128)
# [  5.   5.   3.   6.   9.  14.  25.  13.   4.  17.  23.  74.  34.  13.
#   12.   4.  22.  48.  18.  13.  31.  30.   2.   1.  16.  33.   3.   3.
#   27.  40.   5.   2.   1.   4.  10.  40.  83.  15.   0.   0.  20.  48.
#   55. 139. 139.  33.   3.   5. 139. 139.  42.  33.  14.  33.   9.  24.
#   41.   6.   0.   0.  16. 134.  20.   8.   0.   0.   1.  31.  60.  23.
#    2.   2.  19.   5.   2.  19. 139. 139.  41.  30. 139.  34.   3.   3.
#   11.  50.  44. 128.  61.  20.   4.   1.  38.  69.   2.   6.   1.   0.
#    0.   4.  21.  27.   6.   5.   1.   0.   7.  15.  53.  44.  12.   6.
#   44.  44.  50.   8.   3.  11.  15.  25.  12. 106.  35.   1.   6.  11.
#    0.   0.]
